# %% [markdown]
# ## **RA1: table 221206**

# %% [markdown]
# Dong Gyun Ko <br>
#
# last updated: december 6, 2022 <br>

# %%
# import libraries

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import datetime as dt
import os
import warnings
import requests # python 3.6

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# set the working directory

os.chdir('/content/gdrive/MyDrive/Colab Notebooks/RA1_data/table_221206')

# %% [markdown]
# ## **1. data preprocessing**

# %%
# import the data

df_m_infl = pd.read_excel('df_m_infl.xlsx')

# %%
# 1st dataframe

df_m_infl_1 = df_m_infl.iloc[0:3].set_index([0]).transpose().reset_index()
df_m_infl_1
# Out:
# 0    index    country sources   variable
# 0        1  Australia     IFS        PPI
# 1        2  Australia     IFS  Wholesale
# 2        3    Austria    OECD    CPI_inf
# 3        4    Austria    OECD        PPI
# 4        5    Austria     IFS        PPI
# ..     ...        ...     ...        ...
# 127    128    Romania     IFS        PPI
# 128    129    Romania     IFS  Wholesale
# 129    130        UAE     IFS        CPI
# 130    131  Venezuela     IFS        CPI
# 131    132  Venezuela     IFS  Wholesale
#
# [132 rows x 4 columns]

# %%
# 2nd dataframe

df_m_infl_2 = df_m_infl.iloc[3:].set_index([0]).transpose().reset_index()
df_m_infl_2
# Out:
# 0    index 1969-01-01 00:00:00 1969-02-01 00:00:00 1969-03-01 00:00:00  \
# 0        1                 NaN                 NaN                 NaN
# 1        2           17.552788            17.83791            17.94483
# 2        3                 NaN                 NaN                 NaN
# 3        4                 NaN                 NaN                 NaN
# 4        5                 NaN                 NaN                 NaN
# ..     ...                 ...                 ...                 ...
# 127    128                 NaN                 NaN                 NaN
# 128    129                 NaN                 NaN                 NaN
# 129    130                 NaN                 NaN                 NaN
# 130    131                 NaN                 NaN                 NaN
# 131    132            0.016856            0.016839            0.016906
#
# 0   1969-04-01 00:00:00 1969-05-01 00:00:00 1969-06-01 00:00:00  \
# ...

# %%
# generate the long format table

df_m_infl = pd.merge(df_m_infl_1, df_m_infl_2, how='outer', on=['index']).drop(columns=['index'])
df_m_infl = df_m_infl.set_index(['country', 'sources', 'variable'])
df_m_infl = df_m_infl.transpose().reset_index().rename(columns={0:'month'}).set_index(['month'])
df_m_infl = pd.DataFrame(df_m_infl.stack(level='country').stack(level='sources').stack(level='variable'))
df_m_infl = df_m_infl.rename(columns={0:'value'})
df_m_infl = df_m_infl.reset_index()
df_m_infl = df_m_infl[['sources', 'variable', 'country', 'month', 'value']]
df_m_infl = df_m_infl.sort_values(by=['sources', 'variable', 'country', 'month']).reset_index(drop=True)

df_m_infl['month'] = pd.to_datetime(df_m_infl['month'])
df_m_infl['month'] = df_m_infl['month'].dt.to_period('M')

df_m_infl
# Out:
#                     sources variable country    month     value
# 0      CHNPIEATI01GYM(Fred)  PPI_inf   China  1999-01     -4.92
# 1      CHNPIEATI01GYM(Fred)  PPI_inf   China  1999-02     -4.89
# 2      CHNPIEATI01GYM(Fred)  PPI_inf   China  1999-03     -4.62
# 3      CHNPIEATI01GYM(Fred)  PPI_inf   China  1999-04     -3.86
# 4      CHNPIEATI01GYM(Fred)  PPI_inf   China  1999-05     -3.42
# ...                     ...      ...     ...      ...       ...
# 64346                   NaN      PPI  Russia  2021-09  155.9483
# 64347                   NaN      PPI  Russia  2021-10  156.2198
# 64348                   NaN      PPI  Russia  2021-11  157.9169
# 64349                   NaN      PPI  Russia  2021-12  159.0302
# 64350                   NaN      PPI  Russia  2022-01  161.5622
#
# [64351 rows x 5 columns]

# %%
# generate the sources:variable

# concat_columns func.
def concat_columns(col_1, col_2):

    if not pd.isna(col_2):
       
       result = str(col_1) + ':' + str(col_2)

    return result

df_m_infl['sources:variable'] = df_m_infl.apply(lambda x: concat_columns(x['sources'], x['variable']), axis=1)

df_m_infl = df_m_infl[['sources', 'variable', 'sources:variable', 'country', 'month', 'value']]
df_m_infl
# Out:
#                     sources variable              sources:variable country  \
# 0      CHNPIEATI01GYM(Fred)  PPI_inf  CHNPIEATI01GYM(Fred):PPI_inf   China
# 1      CHNPIEATI01GYM(Fred)  PPI_inf  CHNPIEATI01GYM(Fred):PPI_inf   China
# 2      CHNPIEATI01GYM(Fred)  PPI_inf  CHNPIEATI01GYM(Fred):PPI_inf   China
# 3      CHNPIEATI01GYM(Fred)  PPI_inf  CHNPIEATI01GYM(Fred):PPI_inf   China
# 4      CHNPIEATI01GYM(Fred)  PPI_inf  CHNPIEATI01GYM(Fred):PPI_inf   China
# ...                     ...      ...                           ...     ...
# 64346                   NaN      PPI                       nan:PPI  Russia
# 64347                   NaN      PPI                       nan:PPI  Russia
# 64348                   NaN      PPI                       nan:PPI  Russia
# 64349                   NaN      PPI                       nan:PPI  Russia
# 64350                   NaN      PPI                       nan:PPI  Russia
#
#          month     value
# 0      1999-01     -4.92
# ...

# %% [markdown]
# ## **2. python code**

# %%
# generate the sample period table

sources_variable_list = list(df_m_infl['sources:variable'].unique())

sources_variable_num = 1

for sources_variable in sources_variable_list:

    cond = (df_m_infl['sources:variable'] == sources_variable)

    data = df_m_infl.loc[cond].reset_index(drop=True)

    for i in range(0, data['country'].unique().shape[0]):
  
        # generate the count matrix for monthly data by country
        globals()['cond_country_{}'.format(i+1)] = (data['country'] == data['country'].unique()[i])
        globals()['df_country_{}'.format(i+1)] = data.loc[globals()['cond_country_{}'.format(i+1)]]
        globals()['df_country_count_T_{}'.format(i+1)] = globals()['df_country_{}'.format(i+1)].groupby(globals()['df_country_{}'.format(i+1)]['month']).count()

        # condition for value
        globals()['cond_value_{}'.format(i+1)] = (globals()['df_country_count_T_{}'.format(i+1)]['value'] == 0)

        # filter for value
        globals()['df_country_count_T_{}'.format(i+1)] = globals()['df_country_count_T_{}'.format(i+1)].loc[~globals()['cond_value_{}'.format(i+1)]]
        globals()['df_country_count_T_{}'.format(i+1)] = globals()['df_country_count_T_{}'.format(i+1)].reset_index()

        globals()['tab_{}'.format(i+1)] = pd.DataFrame(np.array([data['country'].unique()[i], 
                                                                 str(globals()['df_country_count_T_{}'.format(i+1)]['month'].unique().min()) + ':' + str(globals()['df_country_count_T_{}'.format(i+1)]['month'].unique().max()),
                                                                 globals()['df_country_count_T_{}'.format(i+1)]['month'].count()]).reshape(1, -1)
                                                                 ).rename(columns={0: 'country', 
                                                                                   1: 'period', 
                                                                                   2: 'obs'}).reset_index(drop=True)

    # print(sources_variable)

    if data['country'].unique().shape[0] == 1:

       globals()['tab'] = globals()['tab_{}'.format(1)]

       globals()['table_{}'.format(sources_variable_num)] = pd.DataFrame(globals()['tab']).reset_index(drop=True)
    
    elif data['country'].unique().shape[0] == 2:

       globals()['tab'] = pd.concat([globals()['tab_{}'.format(1)], globals()['tab_{}'.format(2)]])

       globals()['table_{}'.format(sources_variable_num)] = pd.DataFrame(globals()['tab']).reset_index(drop=True)

    elif data['country'].unique().shape[0] >= 3:

       globals()['tab'] = pd.concat([globals()['tab_{}'.format(1)], globals()['tab_{}'.format(2)]])

       for j in range(3, data['country'].unique().shape[0]+1):
           globals()['tab'] = pd.concat([globals()['tab'], globals()['tab_{}'.format(j)]])

       globals()['table_{}'.format(sources_variable_num)] = pd.DataFrame(globals()['tab']).reset_index(drop=True)
    
    sources_variable_num += 1

# %%
# a list of sources:variable

list(df_m_infl['sources:variable'].unique())
# Out:
# ['CHNPIEATI01GYM(Fred):PPI_inf',
#  'FRED:PPI',
#  'FRED:PPI_inf',
#  'IFS:CPI',
#  'IFS:PPI',
#  'IFS:Wholesale',
#  'OECD:COICOP_inf',
#  'OECD:CPI_inf',
#  'OECD:FRED_PPI',
#  'OECD:PPI',
#  'Wholesale Prices(Fred):PPI',
#  'nan:CPI_inf',
#  'nan:PPI']

# %% [markdown]
# ## **3. results**

# %% [markdown]
# data sources : variable

# %% [markdown]
# ### **3.1. CHNPIEATI01GYM(Fred) : PPI_inf**

# %%
globals()['table_{}'.format(1)]
# Out:
#   country           period  obs
# 0   China  1999-01:2022-06  282

# %% [markdown]
# ### **3.2. FRED : PPI**

# %%
globals()['table_{}'.format(2)]
# Out:
#      country           period  obs
# 0  Indonesia  1971-01:2019-12  588

# %% [markdown]
# ### **3.3. FRED : PPI_inf**

# %%
globals()['table_{}'.format(3)]
# Out:
#   country           period  obs
# 0   Chile  2003-05:2022-09  233

# %% [markdown]
# ### **3.4. IFS : CPI**

# %%
globals()['table_{}'.format(4)]
# Out:
#          country           period  obs
# 0     Bangladesh  1993-07:2022-10  352
# 1       Bulgaria  1991-01:2022-10  382
# 2          Chile  1969-01:2022-10  646
# 3       Colombia  1969-01:2022-10  646
# 4          Egypt  1969-01:2022-09  645
# 5      Hong Kong  1980-10:2022-09  504
# 6      Indonesia  1969-01:2022-10  646
# 7           Iran  1969-01:2022-05  608
# 8         Kuwait  1973-01:2022-07  583
# 9       Malaysia  1969-01:2022-09  645
# 10     Mauritius  1969-01:2022-10  646
# 11       Morocco  1969-01:2022-09  645
# 12       Nigeria  1969-01:2022-10  646
# 13          Oman  2001-01:2022-08  260
# 14      Pakistan  1969-01:2022-10  646
# 15          Peru  1969-01:2022-09  645
# 16   Philippines  1969-01:2022-09  645
# 17         Qatar  2002-12:2022-09  184
# 18       Romania  1990-10:2022-09  384
# 19  Saudi Arabia  1980-02:2022-10  513
# 20     Singapore  1969-01:2022-09  645
# 21      Thailand  1969-01:2022-10  646
# 22           UAE  2007-01:2021-08  176
# ...

# %% [markdown]
# ### **3.5. IFS : PPI**

# %%
globals()['table_{}'.format(5)]
# Out:
#         country           period  obs
# 0     Australia  2001-01:2021-02  242
# 1       Austria  1987-01:2022-04  424
# 2    Bangladesh  1973-01:2006-06  397
# 3      Bulgaria  1995-01:2022-08  332
# 4      Colombia  1969-01:2019-10  610
# 5         Egypt  1991-08:2015-10  291
# 6     Indonesia  1980-01:2019-04  472
# 7          Iran  2007-12:2018-01  122
# 8        Kuwait  1997-03:2017-12  250
# 9      Malaysia  1986-01:2019-03  399
# 10    Mauritius  2007-01:2017-12  132
# 11      Morocco  2004-01:2020-02  194
# 12  Philippines  1993-01:2022-07  355
# 13      Romania  1996-01:2022-10  322
# 14    Singapore  1974-01:2022-08  584
# 15     Thailand  1969-01:2021-05  622

# %% [markdown]
# ### **3.6. IFS : Wholesale**

# %%
globals()['table_{}'.format(6)]
# Out:
#      country           period  obs
# 0  Australia  1969-01:1996-10  334
# 1    Austria  2000-01:2022-05  269
# 2    Morocco  1979-01:1999-12  252
# 3   Pakistan  1969-01:2022-06  642
# 4       Peru  1980-01:2020-02  482
# 5    Romania  1990-01:2022-08  392
# 6  Venezuela  1969-01:2017-04  580
# 7    Vietnam  1969-01:1974-12   72

# %% [markdown]
# ### **3.7. OECD : COICOP_inf**

# %%
globals()['table_{}'.format(7)]
# Out:
#       country           period  obs
# 0  Costa Rica  1977-01:2022-10  550
# 1       Japan  1971-01:2022-10  622

# %% [markdown]
# ### **3.8. OECD : CPI_inf**

# %%
globals()['table_{}'.format(8)]
# Out:
#             country           period  obs
# 0         Argentina  2017-01:2022-10   70
# 1           Austria  1970-01:2022-10  634
# 2           Belgium  1970-01:2022-10  634
# 3            Brazil  1980-12:2022-10  503
# 4            Canada  1970-01:2022-10  634
# 5             China  1987-01:2022-10  430
# 6          Colombia  1971-01:2022-10  622
# 7    Czech Republic  1992-01:2022-10  370
# 8           Denmark  1970-01:2022-10  634
# 9           Estonia  1998-01:2022-10  298
# 10          Finland  1970-01:2022-10  634
# 11           France  1970-01:2022-10  634
# 12          Germany  1970-01:2022-10  634
# 13           Greece  1970-01:2022-10  634
# 14          Hungary  1981-01:2022-10  502
# 15          Iceland  1970-01:2022-10  634
# 16            India  1969-01:2022-09  645
# 17          Ireland  1975-11:2022-10  564
# 18           Israel  1971-01:2022-10  622
# 19            Italy  1970-01:2022-10  634
# 20            Korea  1970-01:2022-10  634
# ...

# %% [markdown]
# ### **3.9. OECD : FRED_PPI**

# %%
globals()['table_{}'.format(9)]
# Out:
#   country           period  obs
# 0  Canada  1969-01:2022-08  644

# %% [markdown]
# ### **3.10. OECD : PPI**

# %%
globals()['table_{}'.format(10)]
# Out:
#             country           period  obs
# 0           Austria  2000-01:2022-09  273
# 1           Belgium  1980-01:2022-09  513
# 2          Colombia  1990-01:2022-10  394
# 3        Costa Rica  1991-01:2022-10  382
# 4    Czech Republic  1990-01:2022-10  394
# 5           Denmark  1974-01:2022-10  586
# 6           Estonia  1994-01:2022-10  346
# 7           Finland  1975-01:2022-09  573
# 8            France  1969-01:2022-09  645
# 9           Germany  1969-01:2022-09  645
# 10           Greece  1969-01:2022-09  645
# 11          Hungary  1995-01:2022-09  333
# 12          Iceland  2006-01:2022-09  201
# 13            India  1969-01:2022-09  645
# 14          Ireland  1969-01:2022-09  645
# 15           Israel  1995-01:2022-09  333
# 16            Italy  1991-01:2022-09  381
# 17            Japan  1969-01:2022-10  646
# 18            Korea  1969-01:2022-09  645
# 19           Latvia  1995-01:2022-09  333
# 20        Lithuania  1995-01:2022-10  334
# ...

# %% [markdown]
# ### **3.11. Wholesale Prices(Fred) : PPI**

# %%
globals()['table_{}'.format(11)]
# Out:
#   country           period  obs
# 0  Brazil  1970-01:2022-06  630

# %% [markdown]
# ### **3.12. nan : CPI_inf**

# %%
globals()['table_{}'.format(12)]
# Out:
#   country           period  obs
# 0  Russia  1993-01:2022-03  351

# %% [markdown]
# ### **3.13. nan : PPI**

# %%
globals()['table_{}'.format(13)]
# Out:
#   country           period  obs
# 0  Russia  1998-01:2022-01  289

# %% [markdown]
# ## **4. export the table**

# %%
# set the working directory

os.chdir('/content/gdrive/MyDrive/Colab Notebooks/RA1_data/table_221206')

# %%
# export the table

for num in range(1, 14):

    globals()['table_{}'.format(num)].to_excel(excel_writer='table_' + str(num) + '_221206' + '.xlsx')
