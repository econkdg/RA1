# %% [markdown]
# # **RA1: data**

# %% [markdown]
# Dong Gyun Ko <br/>
# last updated: october 11, 2022 <br/>

# %%
# import libraries

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pylab as plt
import datetime as dt
import os
import warnings
import requests # python 3.6

import statsmodels.api as sm
from statsmodels.tsa.seasonal import STL

import pandas_datareader as pdr
import pandas_datareader.data as web
from pandas_datareader import wb
from pandas_datareader.data import DataReader

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# set the working directory

os.chdir('/content/gdrive/MyDrive/Colab Notebooks/RA1_data')

# %% [markdown]
# ## **1. data**

# %% [markdown]
# ### **1.1. python code** <br/>

# %%
# import the data

data = pd.read_excel('data.xlsx').drop(columns=['Unnamed: 0']).reset_index(drop=True)

# %%
# import the panel 2 data

df_q_panel_2 = pd.read_excel('df_q_panel_2.xlsx').drop(columns=['Unnamed: 0']).reset_index(drop=True)

# %%
# rename the columns

df_q_panel_2 = df_q_panel_2.rename(columns={'country':'country', 'isocode':'isocode', 'quarter':'quarter', 
                                            'imf_q_ngdp':'ngdp', 'imf_q_exp':'exp', 'imf_q_imp':'imp', 'imf_q_tradeopen':'tradeopen', 
                                            'ci_a_kaopen':'finopen_ci', 'ci_a_kaopen_n':'finopen_ci_n', 
                                            'ewn_a_extasset':'extasset', 'ewn_a_extliab':'extliab', 'ewn_a_gdp':'gdp', 'ewn_a_finopen_fa':'finopen_fa', 
                                            'irr_a_fx_fine':'fxflex_fine', 'irr_a_fx_coarse':'fxflex_coarse', 
                                            'imf_q_pcon':'pcon', 'wb_a_cds_5y':'cds'})

df_q_panel_2 = df_q_panel_2[['country', 'isocode', 'quarter', 'tradeopen', 'finopen_ci', 'finopen_ci_n', 'finopen_fa', 'fxflex_fine', 'fxflex_coarse', 'pcon', 'cds']]

# %%
# seasonal adjustment

# classical decomposition

def cd(df):

    seasonal = sm.tsa.seasonal_decompose(df, model='additive', period=4).seasonal

    return df - seasonal

# STL decomposition

def stld(df):

    stl = STL(df, period=4, seasonal=5)
    res = stl.fit()
    seasonal = res.seasonal

    return df - seasonal

# tradeopen
for i in range(0, df_q_panel_2['isocode'].unique().shape[0]):
  
    globals()['cond_isocode{}'.format(i+1)] = (df_q_panel_2['isocode'] == df_q_panel_2['isocode'].unique()[i])
    globals()['df_q_panel_2_isocode{}'.format(i+1)] = df_q_panel_2.loc[globals()['cond_isocode{}'.format(i+1)]]

    globals()['cond_null{}'.format(i+1)] = (globals()['df_q_panel_2_isocode{}'.format(i+1)]['tradeopen'].isnull() == True)

    globals()['df_q_panel_2_sa{}'.format(i+1)] = globals()['df_q_panel_2_isocode{}'.format(i+1)].loc[(globals()['cond_isocode{}'.format(i+1)] & ~globals()['cond_null{}'.format(i+1)])]

    df_q_panel_2.loc[(globals()['cond_isocode{}'.format(i+1)] & ~globals()['cond_null{}'.format(i+1)]), 'tradeopen'] = stld(globals()['df_q_panel_2_sa{}'.format(i+1)]['tradeopen'])

# finopen_fa
for i in range(0, df_q_panel_2['isocode'].unique().shape[0]):
  
    globals()['cond_isocode{}'.format(i+1)] = (df_q_panel_2['isocode'] == df_q_panel_2['isocode'].unique()[i])
    globals()['df_q_panel_2_isocode{}'.format(i+1)] = df_q_panel_2.loc[globals()['cond_isocode{}'.format(i+1)]]

    globals()['cond_null{}'.format(i+1)] = (globals()['df_q_panel_2_isocode{}'.format(i+1)]['finopen_fa'].isnull() == True)

    globals()['df_q_panel_2_sa{}'.format(i+1)] = globals()['df_q_panel_2_isocode{}'.format(i+1)].loc[(globals()['cond_isocode{}'.format(i+1)] & ~globals()['cond_null{}'.format(i+1)])]

    df_q_panel_2.loc[(globals()['cond_isocode{}'.format(i+1)] & ~globals()['cond_null{}'.format(i+1)]), 'finopen_fa'] = stld(globals()['df_q_panel_2_sa{}'.format(i+1)]['finopen_fa'])

# pcon
for i in range(0, df_q_panel_2['isocode'].unique().shape[0]):
  
    globals()['cond_isocode{}'.format(i+1)] = (df_q_panel_2['isocode'] == df_q_panel_2['isocode'].unique()[i])
    globals()['df_q_panel_2_isocode{}'.format(i+1)] = df_q_panel_2.loc[globals()['cond_isocode{}'.format(i+1)]]

    globals()['cond_null{}'.format(i+1)] = (globals()['df_q_panel_2_isocode{}'.format(i+1)]['pcon'].isnull() == True)

    globals()['df_q_panel_2_sa{}'.format(i+1)] = globals()['df_q_panel_2_isocode{}'.format(i+1)].loc[(globals()['cond_isocode{}'.format(i+1)] & ~globals()['cond_null{}'.format(i+1)])]

    df_q_panel_2.loc[(globals()['cond_isocode{}'.format(i+1)] & ~globals()['cond_null{}'.format(i+1)]), 'pcon'] = stld(globals()['df_q_panel_2_sa{}'.format(i+1)]['pcon'])

# %%
# quarterly panel 2 dataset

df_q_panel_2 = df_q_panel_2.sort_values(by=['isocode', 'quarter']).reset_index(drop=True)

df_q_panel_2
# Out:
#             country isocode quarter  tradeopen  finopen_ci  finopen_ci_n  \
# 0         Argentina     ARG  1950Q1        NaN         NaN           NaN
# 1         Argentina     ARG  1950Q2        NaN         NaN           NaN
# 2         Argentina     ARG  1950Q3        NaN         NaN           NaN
# 3         Argentina     ARG  1950Q4        NaN         NaN           NaN
# 4         Argentina     ARG  1951Q1        NaN         NaN           NaN
# ...             ...     ...     ...        ...         ...           ...
# 14495  South Africa     ZAF  2021Q2      55.22         NaN           NaN
# 14496  South Africa     ZAF  2021Q3      57.41         NaN           NaN
# 14497  South Africa     ZAF  2021Q4      59.45         NaN           NaN
# 14498  South Africa     ZAF  2022Q1      61.19         NaN           NaN
# 14499  South Africa     ZAF  2022Q2      63.72         NaN           NaN
#
#        finopen_fa  fxflex_fine  fxflex_coarse            pcon    cds
# 0             NaN        14.00           5.00             NaN    NaN
# 1             NaN        14.00           5.00             NaN    NaN
# 2             NaN        14.00           5.00             NaN    NaN
# 3             NaN        14.00           5.00             NaN    NaN
# 4             NaN        14.00           5.00             NaN    NaN
# ...           ...          ...            ...             ...    ...
# 14495      245.38          NaN            NaN 769625497221.63 211.64
# 14496      226.94          NaN            NaN 742694325320.05 211.64
# 14497      204.00          NaN            NaN 746925974429.68 211.64
# 14498         NaN          NaN            NaN 755775447564.89    NaN
# 14499         NaN          NaN            NaN 753954273533.09    NaN
#
# [14500 rows x 11 columns]

# %%
# merge the quarterly data with the quarterly panel 2 data

data = pd.merge(data, df_q_panel_2, how='outer', on=['country', 'isocode', 'quarter'])

# %%
# quarterly dataset

data = data[['country', 'isocode', 'quarter', 'region', 'income', 'oecd', 'g7', 'tradeopen', 'finopen_ci', 'finopen_ci_n', 'finopen_fa', 'fxflex_fine', 'fxflex_coarse', 'ggdebt', 'ggcon', 'gdp', 'reer', 'ca', 'pcon', 'cds']]
data = data.sort_values(by=['isocode', 'quarter']).reset_index(drop=True)

data
# Out:
#             country isocode quarter  region  income  oecd  g7  tradeopen  \
# 0         Argentina     ARG  1950Q1       7       2   NaN NaN        NaN
# 1         Argentina     ARG  1950Q2       7       2   NaN NaN        NaN
# 2         Argentina     ARG  1950Q3       7       2   NaN NaN        NaN
# 3         Argentina     ARG  1950Q4       7       2   NaN NaN        NaN
# 4         Argentina     ARG  1951Q1       7       2   NaN NaN        NaN
# ...             ...     ...     ...     ...     ...   ...  ..        ...
# 14495  South Africa     ZAF  2021Q2       5       2   NaN NaN      55.22
# 14496  South Africa     ZAF  2021Q3       5       2   NaN NaN      57.41
# 14497  South Africa     ZAF  2021Q4       5       2   NaN NaN      59.45
# 14498  South Africa     ZAF  2022Q1       5       2   NaN NaN      61.19
# 14499  South Africa     ZAF  2022Q2       5       2   NaN NaN      63.72
#
#        finopen_ci  finopen_ci_n  finopen_fa  fxflex_fine  fxflex_coarse  \
# 0             NaN           NaN         NaN        14.00           5.00
# 1             NaN           NaN         NaN        14.00           5.00
# 2             NaN           NaN         NaN        14.00           5.00
# 3             NaN           NaN         NaN        14.00           5.00
# 4             NaN           NaN         NaN        14.00           5.00
# ...           ...           ...         ...          ...            ...
# 14495         NaN           NaN      245.38          NaN            NaN
# 14496         NaN           NaN      226.94          NaN            NaN
# 14497         NaN           NaN      204.00          NaN            NaN
# 14498         NaN           NaN         NaN          NaN            NaN
# 14499         NaN           NaN         NaN          NaN            NaN
#
#        ggdebt           ggcon              gdp  reer   ca            pcon  \
# 0         NaN             NaN              NaN   NaN  NaN             NaN
# 1         NaN             NaN              NaN   NaN  NaN             NaN
# 2         NaN             NaN              NaN   NaN  NaN             NaN
# 3         NaN             NaN              NaN   NaN  NaN             NaN
# 4         NaN             NaN              NaN   NaN  NaN             NaN
# ...       ...             ...              ...   ...  ...             ...
# 14495   70.88 223698443352.74 1165743462187.47 80.20 5.04 769625497221.63
# 14496   70.73 223959202009.14 1124134900926.21 78.67 2.39 742694325320.05
# 14497   71.31 224091595830.67 1125566644987.62 75.72 3.02 746925974429.68
# 14498     NaN 225833007897.79 1137366344106.18 76.99 2.61 755775447564.89
# 14499     NaN             NaN              NaN 77.99  NaN 753954273533.09
#
#          cds
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 14495 211.64
# 14496 211.64
# 14497 211.64
# 14498    NaN
# 14499    NaN
#
# [14500 rows x 20 columns]

# %% [markdown]
# ### **1.2. var. summary** <br/>

# %% [markdown]
# | |variable|abbreviation|unit|frequency|measure|source|
# |-|--------|------------|----|---------|-------|------|
# |1|region indicator|region|-|-|EAS: 1, SAS: 2, ECS: 3, MEA: 4, SSF: 5, NAC: 6, LCN: 7|WB|
# |2|income indicator|income|-|-|HIC: 1, UMC: 2, LMC: 3, LIC: 4|WB|
# |3|oecd indicator|oecd|-|-|OED: 1|WB|
# |4|g7 indicator|g7|-|-|G7: 1|WB|
# |5|trade openness, (export + import) / GDP|tradeopen|% of GDP|quarterly|SA by STL|IMF|
# |6|financial openness, Chinn-Ito index|finopen_ci|-|annual|-|CI|
# |7|financial openness, Chinn-Ito index, normalized|finopen_ci_n|-|annual|normalzied (0-1)|CI|
# |8|financial openness, (ext. assets + ext. liabilities) / GDP|finopen_fa|% of GDP|annual|SA by STL|EWN|
# |9|FX system flexibility, exchange regime classfication, fine|fxflex_fine|-|annual|fine|IRR|
# |10|FX system flexibility, exchange regime classfication, coarse|fxflex_coarse|-|annual|coarse|IRR|
# |11|general government debt|ggdebt|% of GDP|quarterly|SA by STL|BIS, WB, Eurostat|
# |12|general government consumption, real|ggcon|DCU|quarterly|real / SA by STL|IMF, FRED|
# |13|gross domestic product, real|gdp|DCU|quarterly|real / SA by STL|IMF|
# |14|real effective exchange rate|reer|index|quarterly|real|BIS, IMF|
# |15|current account balance|ca|% of GDP|quarterly|SA by STL|OECD, IMF, FRED|
# |16|private consumption, real|pcon|DCU|quarterly|real / SA by STL|IMF|
# |17|5-year sovereign CDS spread|cds|basis point|annual|-|WB|

# %% [markdown]
# ### **1.3. data summary** <br/>

# %%
# number of countries & sample period

print('number of countries:', data['isocode'].unique().shape[0])
print(data['isocode'].unique())
print('start:', np.min(data['quarter'].unique()))
print('end:', np.max(data['quarter'].unique()))
# Out:
# number of countries: 50
# ['ARG' 'AUS' 'AUT' 'BEL' 'BGR' 'BRA' 'CAN' 'CHE' 'CHL' 'COL' 'CYP' 'CZE'
#  'DEU' 'DNK' 'ESP' 'EST' 'FIN' 'FRA' 'GBR' 'GRC' 'HKG' 'HRV' 'HUN' 'IDN'
#  'IND' 'IRL' 'ISR' 'ITA' 'JPN' 'KOR' 'LTU' 'LUX' 'LVA' 'MEX' 'MLT' 'NLD'
#  'NOR' 'NZL' 'POL' 'PRT' 'ROU' 'RUS' 'SGP' 'SVK' 'SVN' 'SWE' 'THA' 'TUR'
#  'USA' 'ZAF']
# start: 1950Q1
# end: 2022Q2

# %%
# non-null count by each variables

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14500 entries, 0 to 14499
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        14500 non-null  object
#  1   isocode        14500 non-null  object
#  2   quarter        14500 non-null  object
#  3   region         14500 non-null  int64
#  4   income         14500 non-null  int64
#  5   oecd           10440 non-null  float64
#  6   g7             2030 non-null   float64
#  7   tradeopen      6191 non-null   float64
#  8   finopen_ci     8600 non-null   float64
#  9   finopen_ci_n   8600 non-null   float64
#  10  finopen_fa     9292 non-null   float64
#  11  fxflex_fine    13400 non-null  float64
#  12  fxflex_coarse  13400 non-null  float64
#  13  ggdebt         5587 non-null   float64
#  14  ggcon          6442 non-null   float64
#  15  gdp            6389 non-null   float64
#  16  reer           7591 non-null   float64
#  17  ca             6086 non-null   float64
#  18  pcon           6131 non-null   float64
#  19  cds            3204 non-null   float64
# dtypes: float64(15), int64(2), object(3)
# memory usage: 2.2+ MB

# %%
# descriptive statistics

pd.options.display.float_format = '{:.2f}'.format
round(data[['ggdebt', 'ggcon', 'gdp', 'reer', 'ca', 'pcon', 'cds']].describe(), 2)
# Out:
#        ggdebt              ggcon                 gdp    reer      ca  \
# count 5587.00            6442.00             6389.00 7591.00 6086.00
# mean    55.96   4532532484647.42   38866750643511.47   97.43   -0.08
# std     34.45  21624065103603.47  234588086412315.84   19.10    5.51
# min      3.68           29940.86       1309589293.37   32.42  -47.76
# 25%     31.79     10819697477.85      55490076984.74   89.78   -3.13
# 50%     48.33     53732045822.35     267664960565.15   97.94   -0.72
# 75%     71.94    194813015692.21     768761357303.61  103.85    2.44
# max    227.18 251067293692856.69 2896892682330298.00  281.92   32.61
#
#                      pcon      cds
# count             6131.00  3204.00
# mean    23000562720867.86   318.80
# std    133911320765830.58  2102.32
# min          815770839.92     1.77
# 25%        29285201853.65    34.60
# 50%       153703649530.01    81.62
# 75%       476742224468.75   189.79
# max   1559219424873803.00 50990.61

# %% [markdown]
# ## **2. count the data**

# %% [markdown]
# ### **2.1. pcon**

# %%
# generate the count matrix for each country's quarterly data (pcon)

for i in range(0, data['isocode'].unique().shape[0]):
  
    globals()['cond_isocode_{}'.format(i+1)] = (data['isocode'] == data['isocode'].unique()[i])
    globals()['df_isocode_{}'.format(i+1)] = data.loc[globals()['cond_isocode_{}'.format(i+1)]]
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_{}'.format(i+1)].groupby(globals()['df_isocode_{}'.format(i+1)]['quarter']).count()

    globals()['cond_pcon_{}'.format(i+1)] = (globals()['df_isocode_count_T_{}'.format(i+1)]['pcon'] == 0)
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_count_T_{}'.format(i+1)].loc[~globals()['cond_pcon_{}'.format(i+1)]]
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_count_T_{}'.format(i+1)].reset_index()

    print('country', data['country'].unique()[i])
    print('isocode', data['isocode'].unique()[i])
    print('start:', globals()['df_isocode_count_T_{}'.format(i+1)]['quarter'].unique().min())
    print('end:', globals()['df_isocode_count_T_{}'.format(i+1)]['quarter'].unique().max())
    print('obs.:', globals()['df_isocode_count_T_{}'.format(i+1)]['pcon'].count())
    print('des. stat.', globals()['df_isocode_{}'.format(i+1)]['pcon'].describe())
    print('')
# Out:
# country Argentina
# isocode ARG
# start: 2004Q1
# end: 2022Q2
# obs.: 74
# des. stat. count             74.00
# mean    115116532010.27
# std      16965413733.73
# min      75994731834.28
# 25%     104799200815.84
# 50%     121797166192.90
# 75%     128612809847.99
# max     138580481579.11
# Name: pcon, dtype: float64
#
# country Australia
# isocode AUS
# start: 1959Q3
# end: 2022Q2
# obs.: 252
# des. stat. count            252.00
# mean    131513245532.67
# std      74920755764.87
# min      33920849243.57
# 25%      70877371342.15
# 50%     109857888163.80
# 75%     195366330197.24
# max     278948785264.22
# Name: pcon, dtype: float64
#
# country Austria
# isocode AUT
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean    37773656973.27
# std      3661881537.67
# min     30198755849.78
# 25%     34786530122.59
# 50%     38736218742.37
# 75%     40494247601.97
# max     43707524965.75
# Name: pcon, dtype: float64
#
# country Belgium
# isocode BEL
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean    45191662718.88
# std      5078693466.74
# min     36088915590.46
# 25%     41306941368.98
# 50%     45024670451.42
# 75%     49232041421.79
# max     55167305540.21
# Name: pcon, dtype: float64
#
# country Bulgaria
# isocode BGR
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean    10831240640.70
# std      2944067030.76
# min      5645615973.17
# 25%      8176297703.99
# 50%     11916277811.28
# 75%     12790683259.43
# max     16316798278.78
# Name: pcon, dtype: float64
#
# country Brazil
# isocode BRA
# start: 1996Q1
# end: 2022Q2
# obs.: 106
# des. stat. count            106.00
# mean    164168153890.74
# std      34958653126.23
# min     113464645451.77
# 25%     126088755842.04
# 50%     167059432135.00
# 75%     199461341709.58
# max     210824240923.65
# Name: pcon, dtype: float64
#
# country Canada
# isocode CAN
# start: 1981Q1
# end: 2022Q2
# obs.: 166
# des. stat. count            166.00
# mean    196784106502.20
# std      64110105772.18
# min     105872216339.13
# 25%     139208811609.94
# 50%     185853168059.25
# 75%     254036054783.33
# max     316603506604.59
# Name: pcon, dtype: float64
#
# country Switzerland
# isocode CHE
# start: 1980Q1
# end: 2022Q2
# obs.: 170
# des. stat. count           170.00
# mean    73124928874.67
# std     13777351319.98
# min     51888870248.31
# 25%     62506706804.62
# 50%     73205763755.28
# 75%     85079695878.74
# max     97272292712.13
# Name: pcon, dtype: float64
#
# country Chile
# isocode CHL
# start: 1996Q1
# end: 2022Q2
# obs.: 106
# des. stat. count              106.00
# mean    20261008898065.97
# std      7100941863177.08
# min     10392472358831.40
# 25%     13083892041881.26
# 50%     18663390418058.76
# 75%     26424593515879.97
# max     35523950528014.89
# Name: pcon, dtype: float64
#
# country Colombia
# isocode COL
# start: 2005Q1
# end: 2022Q2
# obs.: 70
# des. stat. count                70.00
# mean    126979067289470.05
# std      24578275889888.93
# min      85006131029725.89
# 25%     104483041036763.28
# 50%     129235627144337.78
# 75%     143094580722232.66
# max     185477540921958.34
# Name: pcon, dtype: float64
#
# country Cyprus
# isocode CYP
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count          110.00
# mean    2732128273.92
# std      597246119.33
# min     1622247266.39
# 25%     2209435028.35
# 50%     2886613251.98
# 75%     3197782064.83
# max     3658557515.07
# Name: pcon, dtype: float64
#
# country Czech Republic
# isocode CZE
# start: 1996Q1
# end: 2022Q2
# obs.: 106
# des. stat. count            106.00
# mean    465929241847.27
# std      77733729031.47
# min     335666743397.12
# 25%     391236365230.26
# 50%     485501288016.38
# 75%     523846562470.38
# max     600625273284.20
# Name: pcon, dtype: float64
#
# country Germany
# isocode DEU
# start: 1991Q1
# end: 2022Q2
# obs.: 126
# des. stat. count            126.00
# mean    350279095117.21
# std      29197260702.86
# min     294503642560.34
# 25%     330575057652.95
# 50%     349100666308.63
# 75%     368700560125.31
# max     412860083507.34
# Name: pcon, dtype: float64
#
# country Denmark
# isocode DNK
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count            110.00
# mean    212839508991.01
# std      22844661850.36
# min     171374597566.95
# 25%     189538161584.14
# 50%     216657655526.30
# 75%     226254701436.94
# max     261007140398.07
# Name: pcon, dtype: float64
#
# country Spain
# isocode ESP
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count            110.00
# mean    142660905238.67
# std      17043235825.16
# min     104485960909.41
# 25%     132960499164.34
# 50%     147825887360.07
# 75%     155335376521.87
# max     167156312763.91
# Name: pcon, dtype: float64
#
# country Estonia
# isocode EST
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count          110.00
# mean    1965185264.91
# std      584709281.09
# min      892587814.94
# 25%     1427529906.83
# 50%     2046650547.05
# 75%     2385844300.69
# max     3026102336.70
# Name: pcon, dtype: float64
#
# country Finland
# isocode FIN
# start: 1990Q1
# end: 2022Q2
# obs.: 130
# des. stat. count           130.00
# mean    22040893874.70
# std      4253555317.41
# min     14613373344.32
# 25%     17999936463.52
# 50%     23260108123.78
# 75%     25645564848.67
# max     28181115719.21
# Name: pcon, dtype: float64
#
# country France
# isocode FRA
# start: 1980Q1
# end: 2022Q2
# obs.: 170
# des. stat. count            170.00
# mean    230943752272.70
# std      48518906291.39
# min     149864034620.37
# 25%     192527724699.48
# 50%     235930222484.80
# 75%     276783969678.86
# max     311322116657.16
# Name: pcon, dtype: float64
#
# country United Kingdom
# isocode GBR
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count            110.00
# mean    293874616879.36
# std      44320492577.60
# min     201515611987.18
# 25%     264807249934.58
# 50%     298829110907.44
# 75%     324769994408.47
# max     377324739208.19
# Name: pcon, dtype: float64
#
# country Greece
# isocode GRC
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean    33781227764.33
# std      4522465999.64
# min     26778551279.74
# 25%     30722298325.57
# 50%     32091897663.91
# 75%     36991625344.40
# max     43740049068.42
# Name: pcon, dtype: float64
#
# country Hong Kong SAR, China
# isocode HKG
# start: 1990Q1
# end: 2022Q2
# obs.: 130
# des. stat. count            130.00
# mean    321695336342.03
# std     100394513203.56
# min     161712936053.51
# 25%     243648613402.99
# 50%     290514280308.71
# 75%     414827483621.87
# max     507992441218.16
# Name: pcon, dtype: float64
#
# country Croatia
# isocode HRV
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean    46699945486.01
# std      6565071129.96
# min     32850175014.25
# 25%     41487518738.64
# 50%     48498717461.34
# 75%     50543598697.74
# max     59045617577.25
# Name: pcon, dtype: float64
#
# country Hungary
# isocode HUN
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count             110.00
# mean    3665325094954.28
# std      624198036547.76
# min     2558369570391.95
# 25%     3252982048725.30
# 50%     3678764497401.75
# 75%     3972795644604.31
# max     5180325417974.82
# Name: pcon, dtype: float64
#
# country Indonesia
# isocode IDN
# start: 2000Q1
# end: 2022Q2
# obs.: 90
# des. stat. count                 90.00
# mean    1052373313265590.38
# std      302033236952118.25
# min      628641281497137.50
# 25%      781427196311828.12
# 50%     1000150231166773.38
# 75%     1327107393968624.50
# max     1559219424873802.75
# Name: pcon, dtype: float64
#
# country India
# isocode IND
# start: 1996Q2
# end: 2022Q2
# obs.: 105
# des. stat. count              105.00
# mean    11458419931140.51
# std      5492962199672.28
# min      4801182569172.90
# 25%      6357701260659.83
# 50%     10075868684252.87
# 75%     16023088858553.29
# max     23689669109607.36
# Name: pcon, dtype: float64
#
# country Ireland
# isocode IRL
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean    18006245399.93
# std      3944617584.92
# min      9357189120.36
# 25%     15480151831.18
# 50%     19537289964.79
# 75%     20683301239.70
# max     24026124240.83
# Name: pcon, dtype: float64
#
# country Israel
# isocode ISR
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count            110.00
# mean    127044515414.60
# std      36978273430.69
# min      68792735375.31
# 25%      97133658367.93
# 50%     123245106768.96
# 75%     156848000588.17
# max     202731586784.56
# Name: pcon, dtype: float64
#
# country Italy
# isocode ITA
# start: 1996Q1
# end: 2022Q2
# obs.: 106
# des. stat. count            106.00
# mean    234997961999.21
# std      10411147641.88
# min     205829513905.13
# 25%     230086918630.89
# 50%     236606429399.14
# 75%     242587674756.42
# max     249886373594.41
# Name: pcon, dtype: float64
#
# country Japan
# isocode JPN
# start: 1994Q1
# end: 2022Q2
# obs.: 114
# des. stat. count              114.00
# mean    70788500697865.89
# std      3969741630864.25
# min     61946153996353.84
# 25%     67874917938876.46
# 50%     71874100695452.53
# 75%     73984139397839.12
# max     76788477069850.69
# Name: pcon, dtype: float64
#
# country Korea, Rep.
# isocode KOR
# start: 1960Q1
# end: 2022Q2
# obs.: 250
# des. stat. count               250.00
# mean     93396176047598.41
# std      74258973643198.91
# min       7277341902154.85
# 25%      23118665351585.09
# 50%      74488765231640.50
# 75%     164522744788509.56
# max     227524553024684.84
# Name: pcon, dtype: float64
#
# country Lithuania
# isocode LTU
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count          110.00
# mean    4480334012.26
# std     1368938760.77
# min     2133373823.56
# 25%     3092758504.09
# 50%     4722516371.55
# 75%     5591144710.86
# max     6790372571.62
# Name: pcon, dtype: float64
#
# country Luxembourg
# isocode LUX
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count          110.00
# mean    3485945447.95
# std      698827230.23
# min     2192876458.88
# 25%     2975644246.66
# 50%     3471953312.11
# 75%     4036835415.97
# max     4746603509.23
# Name: pcon, dtype: float64
#
# country Latvia
# isocode LVA
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count          110.00
# mean    2784960049.97
# std      710879387.04
# min     1504937926.74
# 25%     2000540001.97
# 50%     2904147528.14
# 75%     3402109421.23
# max     3806287646.62
# Name: pcon, dtype: float64
#
# country Mexico
# isocode MEX
# start: 1993Q1
# end: 2022Q2
# obs.: 118
# des. stat. count             118.00
# mean    2413929888644.62
# std      482761958040.93
# min     1546759439789.53
# 25%     2091555370608.42
# 50%     2501666314263.76
# 75%     2771435145664.22
# max     3233338488105.95
# Name: pcon, dtype: float64
#
# country Malta
# isocode MLT
# start: 2000Q1
# end: 2022Q2
# obs.: 90
# des. stat. count           90.00
# mean    1059512217.89
# std      176941276.34
# min      815770839.92
# 25%      935401876.57
# 50%     1032195886.77
# 75%     1177937378.34
# max     1457982763.26
# Name: pcon, dtype: float64
#
# country Netherlands
# isocode NLD
# start: 1996Q1
# end: 2022Q2
# obs.: 106
# des. stat. count           106.00
# mean    71109614864.55
# std      4963985059.01
# min     55931978864.77
# 25%     70787281570.99
# 50%     72035910685.87
# 75%     73182315642.20
# max     80606253187.51
# Name: pcon, dtype: float64
#
# country Norway
# isocode NOR
# start: 1978Q1
# end: 2022Q2
# obs.: 178
# des. stat. count            178.00
# mean    207957715480.72
# std      74417699885.92
# min     108746794789.88
# 25%     141042449324.04
# 50%     193199691490.94
# 75%     276482634653.43
# max     350524521165.74
# Name: pcon, dtype: float64
#
# country New Zealand
# isocode NZL
# start: 1987Q2
# end: 2022Q2
# obs.: 141
# des. stat. count           141.00
# mean    25843371300.72
# std      8502671911.55
# min     15122831913.21
# 25%     18384849465.23
# 50%     25299699041.22
# 75%     31484570665.29
# max     43983541510.72
# Name: pcon, dtype: float64
#
# country Poland
# isocode POL
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count            110.00
# mean    207422989681.33
# std      53706080820.53
# min     111873250544.40
# 25%     160663593054.60
# 50%     212317761583.03
# 75%     245371956722.10
# max     313059968093.22
# Name: pcon, dtype: float64
#
# country Portugal
# isocode PRT
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean    27511563359.81
# std      2414554390.89
# min     21296803874.24
# 25%     26625602619.36
# 50%     27880194695.35
# 75%     29100588704.73
# max     32006229414.04
# Name: pcon, dtype: float64
#
# country Romania
# isocode ROU
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count            110.00
# mean     80359033025.97
# std      30478197756.86
# min      39203796843.37
# 25%      47594736590.04
# 50%      85233464209.49
# 75%      96667075849.66
# max     139219736439.85
# Name: pcon, dtype: float64
#
# country Russian Federation
# isocode RUS
# start: 2003Q1
# end: 2021Q3
# obs.: 75
# des. stat. count               75.00
# mean    10578013359071.48
# std      2120211300313.45
# min      5622260149418.08
# 25%      9713371931929.91
# 50%     11407202519462.79
# 75%     12172700182301.75
# max     13053650815444.78
# Name: pcon, dtype: float64
#
# country Singapore
# isocode SGP
# start: 1975Q1
# end: 2021Q2
# obs.: 186
# des. stat. count           186.00
# mean    20810423805.14
# std     12790079600.22
# min      4558230230.06
# 25%      8011168208.93
# 50%     17605198795.92
# 75%     31654781986.87
# max     47055156759.35
# Name: pcon, dtype: float64
#
# country Slovak Republic
# isocode SVK
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count           110.00
# mean     8681141340.99
# std      2014148335.65
# min      5095859302.74
# 25%      6734268086.82
# 50%      9478721793.69
# 75%      9945449926.38
# max     12101666133.45
# Name: pcon, dtype: float64
#
# country Slovenia
# isocode SVN
# start: 1995Q1
# end: 2022Q2
# obs.: 110
# des. stat. count          110.00
# mean    4698144911.84
# std      760815975.30
# min     3285512517.33
# 25%     4065023080.52
# 50%     4889858136.82
# 75%     5146334969.61
# max     6696929404.44
# Name: pcon, dtype: float64
#
# country Sweden
# isocode SWE
# start: 1993Q1
# end: 2022Q2
# obs.: 118
# des. stat. count            118.00
# mean    392360556333.64
# std      78636378025.86
# min     270036729480.83
# 25%     333660108297.89
# 50%     395983172520.76
# 75%     460256041139.24
# max     542352185955.39
# Name: pcon, dtype: float64
#
# country Thailand
# isocode THA
# start: 2003Q1
# end: 2021Q4
# obs.: 76
# des. stat. count              76.00
# mean    1153649703579.39
# std      170615323695.17
# min      837036089342.19
# 25%     1012911924544.63
# 50%     1169779109779.29
# 75%     1288372615692.54
# max     1434900989060.80
# Name: pcon, dtype: float64
#
# country Turkiye
# isocode TUR
# start: 2009Q1
# end: 2022Q2
# obs.: 54
# des. stat. count             54.00
# mean    248321987291.80
# std      51118959205.45
# min     159781260423.54
# 25%     209741239286.62
# 50%     248210283229.57
# 75%     273864470131.15
# max     387728726466.30
# Name: pcon, dtype: float64
#
# country United States
# isocode USA
# start: 1950Q1
# end: 2022Q2
# obs.: 290
# des. stat. count             290.00
# mean    1540190260801.70
# std      938620538662.17
# min      355889414656.99
# 25%      714926535101.50
# 50%     1316898370918.00
# 75%     2418522060786.12
# max     3479294693075.92
# Name: pcon, dtype: float64
#
# country South Africa
# isocode ZAF
# start: 1993Q1
# end: 2022Q2
# obs.: 118
# des. stat. count            118.00
# mean    559732244016.26
# std     143027145363.22
# min     322071036448.74
# 25%     418792593933.71
# 50%     592816837261.56
# 75%     692003933699.00
# max     778076359011.20
# Name: pcon, dtype: float64

# %% [markdown]
# ### **2.2. cds**

# %%
# generate the count matrix for each country's quarterly data (cds)

for i in range(0, data['isocode'].unique().shape[0]):
  
    globals()['cond_isocode_{}'.format(i+1)] = (data['isocode'] == data['isocode'].unique()[i])
    globals()['df_isocode_{}'.format(i+1)] = data.loc[globals()['cond_isocode_{}'.format(i+1)]]
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_{}'.format(i+1)].groupby(globals()['df_isocode_{}'.format(i+1)]['quarter']).count()

    globals()['cond_cds_{}'.format(i+1)] = (globals()['df_isocode_count_T_{}'.format(i+1)]['cds'] == 0)
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_count_T_{}'.format(i+1)].loc[~globals()['cond_cds_{}'.format(i+1)]]
    globals()['df_isocode_count_T_{}'.format(i+1)] = globals()['df_isocode_count_T_{}'.format(i+1)].reset_index()

    print('country', data['country'].unique()[i])
    print('isocode', data['isocode'].unique()[i])

    if globals()['df_isocode_count_T_{}'.format(i+1)]['quarter'].unique().shape[0] == 0:

       continue

    else:

       print('start:', globals()['df_isocode_count_T_{}'.format(i+1)]['quarter'].unique().min())
       print('end:', globals()['df_isocode_count_T_{}'.format(i+1)]['quarter'].unique().max())
       print('obs.:', globals()['df_isocode_count_T_{}'.format(i+1)]['cds'].count())
       print('des. stat.', globals()['df_isocode_{}'.format(i+1)]['cds'].describe())
       print('')
# Out:
# country Argentina
# isocode ARG
# start: 1997Q1
# end: 2021Q4
# obs.: 88
# des. stat. count      88.00
# mean     3250.72
# std      5295.64
# min       263.58
# 25%       482.52
# 50%      1053.44
# 75%      2851.83
# max     21978.63
# Name: cds, dtype: float64
#
# country Australia
# isocode AUS
# start: 2001Q1
# end: 2021Q4
# obs.: 84
# des. stat. count   84.00
# mean    26.47
# std     22.55
# min      2.00
# 25%      4.00
# 50%     19.79
# 75%     38.44
# max     71.83
# Name: cds, dtype: float64
#
# country Austria
# isocode AUT
# start: 2005Q1
# end: 2019Q4
# obs.: 60
# des. stat. count    60.00
# mean     41.56
# std      40.72
# min       2.14
# 25%       4.18
# 50%      28.36
# 75%      79.46
# max     119.23
# Name: cds, dtype: float64
#
# country Belgium
# isocode BEL
# start: 2003Q1
# end: 2019Q4
# obs.: 68
# des. stat. count    68.00
# mean     50.37
# std      61.23
# min       2.54
# 25%       5.53
# 50%      33.51
# 75%      63.23
# max     208.62
# Name: cds, dtype: float64
#
# country Bulgaria
# isocode BGR
# start: 1998Q1
# end: 2021Q4
# obs.: 96
# des. stat. count    96.00
# mean    221.62
# std     197.18
# min      29.48
# 25%      71.75
# 50%     165.00
# 75%     287.98
# max     819.17
# Name: cds, dtype: float64
#
# country Brazil
# isocode BRA
# start: 1997Q1
# end: 2021Q4
# obs.: 100
# des. stat. count    100.00
# mean     417.84
# std      428.65
# min       89.12
# 25%      159.92
# 50%      210.29
# 75%      540.83
# max     2027.50
# Name: cds, dtype: float64
#
# country Canada
# isocode CAN
# country Switzerland
# isocode CHE
# start: 2009Q1
# end: 2016Q4
# obs.: 16
# des. stat. count   16.00
# mean    42.23
# std     15.76
# min     17.01
# 25%     39.13
# 50%     46.92
# 75%     50.02
# max     58.07
# Name: cds, dtype: float64
#
# country Chile
# isocode CHL
# start: 2002Q1
# end: 2021Q4
# obs.: 80
# des. stat. count    80.00
# mean     79.40
# std      45.19
# min      19.75
# 25%      50.16
# 50%      77.87
# 75%      96.56
# max     225.00
# Name: cds, dtype: float64
#
# country Colombia
# isocode COL
# start: 1998Q1
# end: 2021Q4
# obs.: 96
# des. stat. count    96.00
# mean    293.42
# std     235.32
# min      96.72
# 25%     124.12
# 50%     168.54
# 75%     457.52
# max     880.83
# Name: cds, dtype: float64
#
# country Cyprus
# isocode CYP
# start: 2008Q1
# end: 2013Q4
# obs.: 24
# des. stat. count     24.00
# mean     514.96
# std      431.38
# min       91.25
# 25%      110.33
# 50%      394.34
# 75%      955.90
# max     1143.63
# Name: cds, dtype: float64
#
# country Czech Republic
# isocode CZE
# start: 1998Q1
# end: 2021Q4
# obs.: 80
# des. stat. count    80.00
# mean     57.68
# std      39.07
# min       7.46
# 25%      34.28
# 50%      46.76
# 75%      76.92
# max     135.33
# Name: cds, dtype: float64
#
# country Germany
# isocode DEU
# start: 2003Q1
# end: 2021Q4
# obs.: 72
# des. stat. count   72.00
# mean    21.77
# std     19.87
# min      3.27
# 25%      6.45
# 50%     15.19
# 75%     30.27
# max     68.50
# Name: cds, dtype: float64
#
# country Denmark
# isocode DNK
# start: 2005Q1
# end: 2019Q4
# obs.: 52
# des. stat. count   52.00
# mean    35.15
# std     26.37
# min      3.70
# 25%     17.41
# 50%     24.11
# 75%     58.41
# max     86.35
# Name: cds, dtype: float64
#
# country Spain
# isocode ESP
# start: 2004Q1
# end: 2021Q4
# obs.: 72
# des. stat. count    72.00
# mean    105.75
# std     113.71
# min       3.26
# 25%      34.04
# 50%      66.84
# 75%      93.75
# max     420.48
# Name: cds, dtype: float64
#
# country Estonia
# isocode EST
# start: 2008Q1
# end: 2018Q4
# obs.: 40
# des. stat. count    40.00
# mean    146.08
# std     135.43
# min      58.24
# 25%      64.02
# 50%      85.57
# 75%     116.24
# max     448.13
# Name: cds, dtype: float64
#
# country Finland
# isocode FIN
# start: 2007Q1
# end: 2019Q4
# obs.: 44
# des. stat. count   44.00
# mean    27.99
# std     16.61
# min      4.06
# 25%     11.90
# 50%     25.00
# 75%     40.67
# max     56.34
# Name: cds, dtype: float64
#
# country France
# isocode FRA
# start: 2003Q1
# end: 2021Q4
# obs.: 72
# des. stat. count    72.00
# mean     39.48
# std      41.07
# min       2.10
# 25%       5.78
# 50%      26.64
# 75%      46.65
# max     148.45
# Name: cds, dtype: float64
#
# country United Kingdom
# isocode GBR
# start: 2008Q1
# end: 2021Q4
# obs.: 56
# des. stat. count   56.00
# mean    39.63
# std     24.87
# min     10.72
# 25%     18.75
# 50%     33.89
# 75%     61.77
# max     84.44
# Name: cds, dtype: float64
#
# country Greece
# isocode GRC
# start: 1998Q1
# end: 2021Q4
# obs.: 84
# des. stat. count      84.00
# mean     2890.33
# std     10841.85
# min         8.00
# 25%        39.40
# 50%       173.33
# 75%       710.30
# max     50990.61
# Name: cds, dtype: float64
#
# country Hong Kong SAR, China
# isocode HKG
# start: 2005Q1
# end: 2013Q4
# obs.: 24
# des. stat. count   24.00
# mean    39.64
# std     21.72
# min     10.08
# 25%     10.25
# 50%     49.35
# 75%     57.85
# max     60.94
# Name: cds, dtype: float64
#
# country Croatia
# isocode HRV
# start: 1998Q1
# end: 2021Q4
# obs.: 96
# des. stat. count    96.00
# mean    229.19
# std     167.55
# min      29.29
# 25%      84.88
# 50%     203.31
# 75%     325.54
# max     652.70
# Name: cds, dtype: float64
#
# country Hungary
# isocode HUN
# start: 1998Q1
# end: 2021Q4
# obs.: 96
# des. stat. count    96.00
# mean    136.41
# std     124.24
# min      18.67
# 25%      35.59
# 50%      85.24
# 75%     191.04
# max     444.56
# Name: cds, dtype: float64
#
# country Indonesia
# isocode IDN
# start: 1998Q1
# end: 2021Q4
# obs.: 88
# des. stat. count     88.00
# mean     349.07
# std      353.70
# min       79.23
# 25%      136.00
# 50%      178.40
# 75%      367.00
# max     1275.29
# Name: cds, dtype: float64
#
# country India
# isocode IND
# country Ireland
# isocode IRL
# start: 2006Q1
# end: 2021Q4
# obs.: 64
# des. stat. count    64.00
# mean    140.15
# std     193.74
# min       2.00
# 25%      29.66
# 50%      54.16
# 75%     168.11
# max     713.83
# Name: cds, dtype: float64
#
# country Israel
# isocode ISR
# start: 2004Q1
# end: 2021Q4
# obs.: 72
# des. stat. count    72.00
# mean     80.61
# std      43.85
# min      22.63
# 25%      51.30
# 50%      64.95
# 75%     116.52
# max     163.21
# Name: cds, dtype: float64
#
# country Italy
# isocode ITA
# start: 2003Q1
# end: 2021Q4
# obs.: 76
# des. stat. count    76.00
# mean    127.03
# std     103.86
# min       7.80
# 25%      10.42
# 50%     122.24
# 75%     172.21
# max     404.75
# Name: cds, dtype: float64
#
# country Japan
# isocode JPN
# start: 2001Q1
# end: 2021Q4
# obs.: 84
# des. stat. count    84.00
# mean     35.58
# std      28.32
# min       3.33
# 25%      17.38
# 50%      23.58
# 75%      46.73
# max     103.21
# Name: cds, dtype: float64
#
# country Korea, Rep.
# isocode KOR
# start: 1998Q1
# end: 2021Q4
# obs.: 88
# des. stat. count    88.00
# mean    101.17
# std     127.22
# min      20.48
# 25%      32.71
# 50%      57.81
# 75%     107.57
# max     629.89
# Name: cds, dtype: float64
#
# country Lithuania
# isocode LTU
# start: 2004Q1
# end: 2021Q4
# obs.: 72
# des. stat. count    72.00
# mean    120.81
# std     120.75
# min       5.88
# 25%      50.14
# 50%      67.42
# 75%     215.69
# max     474.58
# Name: cds, dtype: float64
#
# country Luxembourg
# isocode LUX
# country Latvia
# isocode LVA
# start: 2006Q1
# end: 2016Q4
# obs.: 44
# des. stat. count    44.00
# mean    223.10
# std     200.78
# min       6.50
# 25%      85.21
# 50%     122.12
# 75%     355.41
# max     692.68
# Name: cds, dtype: float64
#
# country Mexico
# isocode MEX
# start: 1997Q1
# end: 2021Q4
# obs.: 100
# des. stat. count   100.00
# mean    174.62
# std     114.67
# min      47.84
# 25%     111.69
# 50%     129.50
# 75%     194.17
# max     544.36
# Name: cds, dtype: float64
#
# country Malta
# isocode MLT
# country Netherlands
# isocode NLD
# start: 2008Q1
# end: 2019Q4
# obs.: 48
# des. stat. count   48.00
# mean    38.68
# std     23.95
# min      4.76
# 25%     18.93
# 50%     37.11
# 75%     53.29
# max     86.60
# Name: cds, dtype: float64
#
# country Norway
# isocode NOR
# start: 2009Q1
# end: 2019Q4
# obs.: 36
# des. stat. count   36.00
# mean    18.43
# std      8.74
# min      3.75
# 25%     13.39
# 50%     16.69
# 75%     25.77
# max     30.53
# Name: cds, dtype: float64
#
# country New Zealand
# isocode NZL
# start: 2008Q1
# end: 2021Q4
# obs.: 56
# des. stat. count   56.00
# mean    49.72
# std     21.81
# min     26.33
# 25%     33.97
# 50%     38.13
# 75%     75.47
# max     89.08
# Name: cds, dtype: float64
#
# country Poland
# isocode POL
# start: 1997Q1
# end: 2021Q4
# obs.: 100
# des. stat. count   100.00
# mean     78.91
# std      50.00
# min      14.21
# 25%      45.00
# 50%      65.35
# 75%      98.04
# max     194.72
# Name: cds, dtype: float64
#
# country Portugal
# isocode PRT
# start: 2003Q1
# end: 2021Q4
# obs.: 76
# des. stat. count    76.00
# mean    185.79
# std     258.75
# min       6.22
# 25%       8.57
# 50%      67.25
# 75%     257.88
# max     874.48
# Name: cds, dtype: float64
#
# country Romania
# isocode ROU
# start: 2002Q1
# end: 2021Q4
# obs.: 80
# des. stat. count    80.00
# mean    180.53
# std     116.93
# min      33.87
# 25%      93.21
# 50%     121.54
# 75%     284.00
# max     405.00
# Name: cds, dtype: float64
#
# country Russian Federation
# isocode RUS
# start: 1997Q1
# end: 2021Q4
# obs.: 100
# des. stat. count    100.00
# mean     859.56
# std     2047.65
# min       54.64
# 25%      137.14
# 50%      206.67
# 75%      367.06
# max     8780.28
# Name: cds, dtype: float64
#
# country Singapore
# isocode SGP
# country Slovak Republic
# isocode SVK
# start: 2001Q1
# end: 2021Q4
# obs.: 84
# des. stat. count    84.00
# mean     65.55
# std      48.40
# min       7.42
# 25%      39.02
# 50%      48.58
# 75%      88.40
# max     194.05
# Name: cds, dtype: float64
#
# country Slovenia
# isocode SVN
# start: 2005Q1
# end: 2018Q4
# obs.: 56
# des. stat. count    56.00
# mean    117.21
# std     104.53
# min       4.38
# 25%      51.63
# 50%      94.81
# 75%     152.91
# max     361.95
# Name: cds, dtype: float64
#
# country Sweden
# isocode SWE
# start: 2004Q1
# end: 2019Q4
# obs.: 60
# des. stat. count   60.00
# mean    20.89
# std     19.53
# min      1.77
# 25%      2.29
# 50%     15.45
# 75%     36.76
# max     68.79
# Name: cds, dtype: float64
#
# country Thailand
# isocode THA
# start: 1998Q1
# end: 2021Q4
# obs.: 88
# des. stat. count    88.00
# mean    113.86
# std     118.45
# min      34.60
# 25%      45.16
# 50%     111.67
# 75%     133.89
# max     606.00
# Name: cds, dtype: float64
#
# country Turkiye
# isocode TUR
# start: 1998Q1
# end: 2021Q4
# obs.: 96
# des. stat. count    96.00
# mean    380.37
# std     226.02
# min     169.31
# 25%     203.59
# 50%     292.46
# 75%     441.53
# max     857.08
# Name: cds, dtype: float64
#
# country United States
# isocode USA
# start: 2009Q1
# end: 2019Q4
# obs.: 40
# des. stat. count   40.00
# mean    26.82
# std     12.86
# min      4.75
# 25%     19.17
# 50%     23.78
# 75%     39.01
# max     48.90
# Name: cds, dtype: float64
#
# country South Africa
# isocode ZAF
# start: 1998Q1
# end: 2021Q4
# obs.: 96
# des. stat. count    96.00
# mean    191.10
# std      82.29
# min      46.14
# 25%     150.21
# 50%     191.49
# 75%     231.54
# max     421.86
# Name: cds, dtype: float64

# %% [markdown]
# ## **3. plot the data**

# %%
# generate the data temp

df_q_panel_2= pd.read_excel('df_q_panel_2.xlsx')

data_temp = df_q_panel_2[['country', 'isocode', 'quarter', 
                          'imf_q_ngdp', 'imf_q_exp', 'imf_q_imp', 'imf_q_tradeopen', 
                          'ci_a_kaopen', 'ci_a_kaopen_n', 
                          'ewn_a_extasset', 'ewn_a_extliab', 'ewn_a_gdp', 'ewn_a_finopen_fa', 
                          'irr_a_fx_fine', 'irr_a_fx_coarse', 
                          'imf_q_pcon', 'wb_a_cds_5y']]
data_temp = data_temp.rename(columns={'country':'country', 'isocode':'isocode', 'quarter':'quarter', 
                                      'imf_q_ngdp':'ngdp', 'imf_q_exp':'exp', 'imf_q_imp':'imp', 'imf_q_tradeopen':'tradeopen', 
                                      'ci_a_kaopen':'finopen_ci', 'ci_a_kaopen_n':'finopen_ci_n', 
                                      'ewn_a_extasset':'extasset', 'ewn_a_extliab':'extliab', 'ewn_a_gdp':'gdp', 'ewn_a_finopen_fa':'finopen_fa', 
                                      'irr_a_fx_fine':'fxflex_fine', 'irr_a_fx_coarse':'fxflex_coarse', 
                                      'imf_q_pcon':'pcon', 'wb_a_cds_5y':'cds'})


data_temp = data_temp.sort_values(by=['isocode', 'quarter']).reset_index(drop=True)

# %% [markdown]
# ### **3.1. pcon** <br/>

# %%
# pcon

warnings.filterwarnings(action='ignore')

for i in range(0, data['isocode'].unique().shape[0]):

    plt.figure(figsize=(20, 250)).set_facecolor('white')
    plt.style.use('seaborn-whitegrid')

    plt.subplot(data['isocode'].unique().shape[0], 1, i+1)
    plt.title('Private Consumption ({})'.format(data['country'].unique()[i]), fontsize=15)
  
    globals()['cond_isocode{}'.format(i+1)] = (data['isocode'] == data['isocode'].unique()[i])
    globals()['data_isocode{}'.format(i+1)] = data.loc[globals()['cond_isocode{}'.format(i+1)]]
    globals()['data_isocode{}'.format(i+1)]['quarter'] = pd.to_datetime(globals()['data_isocode{}'.format(i+1)]['quarter'])

    plt.plot(globals()['data_isocode{}'.format(i+1)]['quarter'], globals()['data_isocode{}'.format(i+1)]['pcon'], label=globals()['data_isocode{}'.format(i+1)]['isocode'].unique()[0] + ' (Seasonal Adjusted)', color='slateblue')

    globals()['cond_temp_isocode{}'.format(i+1)] = (data_temp['isocode'] == data_temp['isocode'].unique()[i])
    globals()['data_temp_isocode{}'.format(i+1)] = data_temp.loc[globals()['cond_temp_isocode{}'.format(i+1)]]
    globals()['data_temp_isocode{}'.format(i+1)]['quarter'] = pd.to_datetime(globals()['data_temp_isocode{}'.format(i+1)]['quarter'])

    plt.plot(globals()['data_temp_isocode{}'.format(i+1)]['quarter'], globals()['data_temp_isocode{}'.format(i+1)]['pcon'], label=globals()['data_temp_isocode{}'.format(i+1)]['isocode'].unique()[0], color='slateblue', linestyle='dashed', alpha=0.7)

    plt.xlabel('Time', fontsize=15)
    plt.ylabel('Domestic Currency Unit', fontsize=15)
    plt.xlim([dt.date(1949, 1, 1), dt.date(2023, 4, 1)])
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(loc='upper left', ncol=1, fontsize=15)

plt.tight_layout()
# plt.grid()

# %% [markdown]
# ### **3.2. cds** <br/>

# %%
# cds

warnings.filterwarnings(action='ignore')

for i in range(0, data['isocode'].unique().shape[0]):

    plt.figure(figsize=(20, 250)).set_facecolor('white')
    plt.style.use('seaborn-whitegrid')

    plt.subplot(data['isocode'].unique().shape[0], 1, i+1)
    plt.title('Credit Default Swap Spread ({})'.format(data['country'].unique()[i]), fontsize=15)
  
    globals()['cond_isocode{}'.format(i+1)] = (data['isocode'] == data['isocode'].unique()[i])
    globals()['data_isocode{}'.format(i+1)] = data.loc[globals()['cond_isocode{}'.format(i+1)]]
    globals()['data_isocode{}'.format(i+1)]['quarter'] = pd.to_datetime(globals()['data_isocode{}'.format(i+1)]['quarter'])

    plt.plot(globals()['data_isocode{}'.format(i+1)]['quarter'], globals()['data_isocode{}'.format(i+1)]['cds'], label=globals()['data_isocode{}'.format(i+1)]['isocode'].unique()[0], color='darkorange')
    plt.xlabel('Time', fontsize=15)
    plt.ylabel('Basis Point (bp)', fontsize=15)
    plt.xlim([dt.date(1949, 1, 1), dt.date(2023, 4, 1)])
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(loc='upper left', ncol=1, fontsize=15)

plt.tight_layout()
# plt.grid()

# %% [markdown]
# ## **4. export the data**

# %%
# quarterly dataset

data['quarter'] = pd.to_datetime(data['quarter'])
data['quarter'] = data['quarter'].dt.to_period('Q')

data = data.sort_values(by=['isocode', 'quarter']).reset_index(drop=True)

data
# Out:
#             country isocode quarter  region  income  oecd  g7  tradeopen  \
# 0         Argentina     ARG  1950Q1       7       2   NaN NaN        NaN
# 1         Argentina     ARG  1950Q2       7       2   NaN NaN        NaN
# 2         Argentina     ARG  1950Q3       7       2   NaN NaN        NaN
# 3         Argentina     ARG  1950Q4       7       2   NaN NaN        NaN
# 4         Argentina     ARG  1951Q1       7       2   NaN NaN        NaN
# ...             ...     ...     ...     ...     ...   ...  ..        ...
# 14495  South Africa     ZAF  2021Q2       5       2   NaN NaN      55.22
# 14496  South Africa     ZAF  2021Q3       5       2   NaN NaN      57.41
# 14497  South Africa     ZAF  2021Q4       5       2   NaN NaN      59.45
# 14498  South Africa     ZAF  2022Q1       5       2   NaN NaN      61.19
# 14499  South Africa     ZAF  2022Q2       5       2   NaN NaN      63.72
#
#        finopen_ci  finopen_ci_n  finopen_fa  fxflex_fine  fxflex_coarse  \
# 0             NaN           NaN         NaN        14.00           5.00
# 1             NaN           NaN         NaN        14.00           5.00
# 2             NaN           NaN         NaN        14.00           5.00
# 3             NaN           NaN         NaN        14.00           5.00
# 4             NaN           NaN         NaN        14.00           5.00
# ...           ...           ...         ...          ...            ...
# 14495         NaN           NaN      245.38          NaN            NaN
# 14496         NaN           NaN      226.94          NaN            NaN
# 14497         NaN           NaN      204.00          NaN            NaN
# 14498         NaN           NaN         NaN          NaN            NaN
# 14499         NaN           NaN         NaN          NaN            NaN
#
#        ggdebt           ggcon              gdp  reer   ca            pcon  \
# 0         NaN             NaN              NaN   NaN  NaN             NaN
# 1         NaN             NaN              NaN   NaN  NaN             NaN
# 2         NaN             NaN              NaN   NaN  NaN             NaN
# 3         NaN             NaN              NaN   NaN  NaN             NaN
# 4         NaN             NaN              NaN   NaN  NaN             NaN
# ...       ...             ...              ...   ...  ...             ...
# 14495   70.88 223698443352.74 1165743462187.47 80.20 5.04 769625497221.63
# 14496   70.73 223959202009.14 1124134900926.21 78.67 2.39 742694325320.05
# 14497   71.31 224091595830.67 1125566644987.62 75.72 3.02 746925974429.68
# 14498     NaN 225833007897.79 1137366344106.18 76.99 2.61 755775447564.89
# 14499     NaN             NaN              NaN 77.99  NaN 753954273533.09
#
#          cds
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 14495 211.64
# 14496 211.64
# 14497 211.64
# 14498    NaN
# 14499    NaN
#
# [14500 rows x 20 columns]

# %%
# export the quarterly data

data.to_excel(excel_writer='data_221011.xlsx')

# %% [markdown]
# ## **5. references**

# %% [markdown]
# * https://data.imf.org/?sk=4c514d48-b6ba-49ed-8ab9-52b0c1a0179b&sId=1409151240976 <br/>
# * https://www.worldbank.org/en/research/brief/fiscal-space <br/>
# * https://documents1.worldbank.org/curated/en/601211501678994591/pdf/WPS8157.pdf <br/>
# * https://www.brookings.edu/research/the-external-wealth-of-nations-database/
# <br/>
# * https://www.imf.org/en/Publications/WP/Issues/2017/05/10/International-Financial-Integration-in-the-Aftermath-of-the-Global-Financial-Crisis-44906 <br/>
# * https://carmenreinhart.com/exchange-rate/# <br/>
